# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Krom et al data

# 2 minutes 
#                     X              AVERAGE_SDV_AR3_C_MOL    AVERAGE_SDV_AR4_CL_MOL   AVERAGE_SDV_AR5_CT_MOL            MOL                       OL                      _MOL           AVERAGE_SDV_AR10_THETAL            _DIS                     _GB                     _CARB                AVERAGE_UVARM1           AVERAGE_UVARM2           AVERAGE_UVARM3           AVERAGE_UVARM4           AVERAGE_UVARM5    

#                  120.                       5.42304182               4.52873135             893.896362E-03            32.2636566E-06          140.585007E-03           753.349243E-03             5.33520412E-06          17.1282787E-03          999.999634E-03           535.943359E-06           691.753418E-03           577.759155E-03           114.047935E-03             4.11578178E-06          17.9380665E-03 
# 10 minutes
#                      X              AVERAGE_SDV_AR3_C_MOL    AVERAGE_SDV_AR4_CL_MOL   AVERAGE_SDV_AR5_CT_MOL            MOL                       OL                      _MOL           AVERAGE_SDV_AR10_THETAL            _DIS                     _GB                     _CARB                AVERAGE_UVARM1           AVERAGE_UVARM2           AVERAGE_UVARM3           AVERAGE_UVARM4           AVERAGE_UVARM5    

#                  600.                       9.00249577               7.59924507               1.40461278              53.8663902E-06          140.585297E-03             1.26405108               8.95447922E-06          28.5994415E-03          999.999878E-03           899.325806E-06             1.14877129             969.471558E-03           179.198517E-03             6.87072468E-06          17.9380779E-03 
# 30 minutes
#                      X              AVERAGE_SDV_AR3_C_MOL    AVERAGE_SDV_AR4_CL_MOL   AVERAGE_SDV_AR5_CT_MOL            MOL                       OL                      _MOL           AVERAGE_SDV_AR10_THETAL            _DIS                     _GB                     _CARB                AVERAGE_UVARM1           AVERAGE_UVARM2           AVERAGE_UVARM3           AVERAGE_UVARM4           AVERAGE_UVARM5    

#                    1.79999995E+03          10.2599535                8.67543602               1.58353937              61.2759705E-06          140.585297E-03             1.44294226              10.223074E-06            32.5321617E-03          999.999878E-03             1.02673781E-03           1.30904055               1.10690069             202.04155E-03              7.81578779E-06          17.9380779E-03 
# 120 minutes
#        X              AVERAGE_SDV_AR3_C_MOL    AVERAGE_SDV_AR4_CL_MOL   AVERAGE_SDV_AR5_CT_MOL            MOL                       OL                      _MOL           AVERAGE_SDV_AR10_THETAL            _DIS                     _GB                     _CARB                AVERAGE_UVARM1           AVERAGE_UVARM2           AVERAGE_UVARM3           AVERAGE_UVARM4           AVERAGE_UVARM5    

#                    7.19999981E+03          10.3146791                8.7219696                1.591012                61.6177292E-06          140.585297E-03             1.45050049              10.2816687E-06           32.7139702E-03          999.999878E-03             1.03238785E-03           1.31633961               1.11325645             203.098053E-03             7.85723877E-06          17.9380779E-03 

# can you help me write these lists in python?


# Time points in minutes
times = [0, 2, 10, 30, 120]

krom_C_mol = np.array([0.0, 5.42304182, 9.00249577, 10.2599535, 10.3146791])
krom_CL_mol = np.array([0.0, 4.52873135, 7.59924507, 8.67543602, 8.7219696])
krom_CT_mol = np.array([0.0, 893.896362E-03, 1.40461278, 1.58353937, 1.591012])
krom_CT_dis_mol = np.array([0.0, 32.2636566e-06, 53.8663902e-06, 61.2759705e-06, 61.6177292e-06])
krom_CT_gb_mol = np.array([0.0, 140.585297e-03, 140.585297e-03, 140.585297e-03, 140.585297e-03])
krom_CT_carb_mol = np.array([0.0, 753.349243e-03, 1.26405108, 1.44294226, 1.45050049])

krom_thetaL = np.array([0.0, 5.33520412e-06, 8.95447922e-06, 10.223074e-06, 10.2816687e-06])
krom_thetaT_dis = np.array([0.0, 17.1282787e-03, 28.5994415e-03, 32.5321617e-03, 32.7139702e-03])
krom_thetaT_gb = np.array([0.0, 999.999634e-03, 999.999878e-03, 999.999878e-03, 999.999878e-03])
krom_thetaT_carb = np.array([0.0, 535.943359e-06, 899.325806e-06, 1.02673781e-03, 1.03238785e-03])

# UVARM data for comparison and calculation outputs
krom_C_wtppm = np.array([0.0, 691.753418e-03, 1.14877129, 1.30904055, 1.31633961])
krom_CL_wtppm = np.array([0.0, 577.759155e-03, 969.471558e-03, 1.10690069, 1.11325645])
krom_CT_wtppm = np.array([0.0, 114.047935e-03, 179.198517e-03, 202.04155e-03, 203.098053e-03])
krom_CT_dis_wtppm = np.array([0.0, 4.11578178e-06, 6.87072468e-06, 7.81578779e-06, 7.85723877e-06])
krom_CT_gb_wtppm = np.array([0.0, 17.9380665e-03, 17.9380779e-03, 17.9380779e-03, 17.9380779e-03])
krom_CT_carb_wtppm = np.array([0.0, 0.09610575271822, 0.16125356837532, 0.18409565631221, 0.18515211786123])

# krom_CT_carb_wtppm = []
# for i in range(len(krom_CT_carb_mol)):
#     krom_CT_carb_wtppm.append(krom_CT_wtppm[i] - krom_CT_dis_wtppm[i] - krom_CT_gb_wtppm[i])
# print(krom_CT_carb_wtppm)

plt.figure(figsize = (6, 4))

plt.plot(times, krom_C_wtppm, 'o-', label = 'C wtppm')
plt.title('Hydrogen concentration vs time\nFormulation: Kumnick, Krom et al. (1999)')
plt.ylim(-0.1, 1.5)
# We now annotate the points with the time values and the C wtppm values
for i, time in enumerate(times):
    plt.annotate(f"{time} min\n{round(krom_C_wtppm[i], 3)} wt.ppm", (times[i]+6, krom_C_wtppm[i]-0.2))
#plt.xticks(times)
plt.yticks(np.arange(0, 1.6, 0.3))
plt.ylabel('H concentration (wt.ppm)')
plt.xlabel('Precharging time (min)')
# Out:
# Text(0.5, 0, 'Precharging time (min)')

# %%
# Dadfarnia et al data

# # 2 minutes
#                                                                                                               AVERAGE_SDV_AR6_CT_DIS_  AVERAGE_SDV_AR7_CT_GB_M  AVERAGE_SDV_AR8_CT_CARB                           AVERAGE_SDV_AR11_THETAT  AVERAGE_SDV_AR12_THETAT  AVERAGE_SDV_AR13_THETAT                                                                                                                             
#                      X              AVERAGE_SDV_AR3_C_MOL    AVERAGE_SDV_AR4_CL_MOL   AVERAGE_SDV_AR5_CT_MOL            MOL                       OL                      _MOL           AVERAGE_SDV_AR10_THETAL            _DIS                     _GB                     _CARB                AVERAGE_UVARM1           AVERAGE_UVARM2           AVERAGE_UVARM3           AVERAGE_UVARM4           AVERAGE_UVARM5    

#                  120.                       5.43810701               4.52140713             915.651672E-03            22.884861E-03           140.585007E-03           752.216309E-03             5.32919693E-06          17.10429E-03            999.999634E-03           535.318604E-06           693.843445E-03           576.934326E-03           116.850189E-03             2.91979527E-03          17.9380665E-03 

# # 10 minutes

#                      X              AVERAGE_SDV_AR3_C_MOL    AVERAGE_SDV_AR4_CL_MOL   AVERAGE_SDV_AR5_CT_MOL            MOL                       OL                      _MOL           AVERAGE_SDV_AR10_THETAL            _DIS                     _GB                     _CARB                AVERAGE_UVARM1           AVERAGE_UVARM2           AVERAGE_UVARM3           AVERAGE_UVARM4           AVERAGE_UVARM5    

#                  600.                       9.03329659               7.59059477               1.44152522              38.2327156E-03          140.585297E-03             1.26258695               8.94569111E-06          28.5720978E-03          999.999878E-03           898.400024E-06             1.15232539             968.599548E-03           183.898773E-03             4.8773036E-03           17.9380779E-03 

# # 30 minutes
#                                                                                                               AVERAGE_SDV_AR6_CT_DIS_  AVERAGE_SDV_AR7_CT_GB_M  AVERAGE_SDV_AR8_CT_CARB                           AVERAGE_SDV_AR11_THETAT  AVERAGE_SDV_AR12_THETAT  AVERAGE_SDV_AR13_THETAT                                                                                                                             
#                      X              AVERAGE_SDV_AR3_C_MOL    AVERAGE_SDV_AR4_CL_MOL   AVERAGE_SDV_AR5_CT_MOL            MOL                       OL                      _MOL           AVERAGE_SDV_AR10_THETAL            _DIS                     _GB                     _CARB                AVERAGE_UVARM1           AVERAGE_UVARM2           AVERAGE_UVARM3           AVERAGE_UVARM4           AVERAGE_UVARM5    

#                    1.79999995E+03          10.303607                 8.67461681               1.62715495              43.5308571E-03          140.585297E-03             1.44284761              10.2214746E-06           32.5279045E-03          999.999878E-03             1.02668393E-03           1.3142153                1.10681903             207.542389E-03             5.55293226E-03          17.9380779E-03 

# # 120 minutes

#                                                                                                               AVERAGE_SDV_AR6_CT_DIS_  AVERAGE_SDV_AR7_CT_GB_M  AVERAGE_SDV_AR8_CT_CARB                           AVERAGE_SDV_AR11_THETAT  AVERAGE_SDV_AR12_THETAT  AVERAGE_SDV_AR13_THETAT                                                                                                                             
#                      X              AVERAGE_SDV_AR3_C_MOL    AVERAGE_SDV_AR4_CL_MOL   AVERAGE_SDV_AR5_CT_MOL            MOL                       OL                      _MOL           AVERAGE_SDV_AR10_THETAL            _DIS                     _GB                     _CARB                AVERAGE_UVARM1           AVERAGE_UVARM2           AVERAGE_UVARM3           AVERAGE_UVARM4           AVERAGE_UVARM5    

#                    7.19999981E+03          10.3636103                8.7219696                1.63580596              43.7821312E-03          140.585297E-03             1.45050049              10.2816687E-06           32.7139702E-03          999.999878E-03             1.03238785E-03           1.32145774               1.11325645             208.602585E-03             5.58447313E-03          17.9380779E-03 


# Time points in minutes
times = [0, 2, 10, 30, 120]

dadfarnia_C_mol = np.array([0.0, 5.43810701, 9.03329659, 10.303607, 10.3636103])
dadfarnia_CL_mol = np.array([0.0, 4.52140713, 7.59059477, 8.67461681, 8.7219696])
dadfarnia_CT_mol = np.array([0.0, 915.651672E-03, 1.44152522, 1.62715495, 1.63580596])
dadfarnia_CT_dis_mol = np.array([0.0, 22.884861E-03, 38.2327156E-03, 43.5308571E-03, 43.7821312E-03])
dadfarnia_CT_gb_mol = np.array([0.0, 140.585007e-03, 140.585297e-03, 140.585297e-03, 140.585297e-03])
dadfarnia_CT_carb_mol = np.array([0.0, 752.216309e-03, 1.26258695, 1.44284761, 1.45050049])

dadfarnia_thetaL = np.array([0.0, 5.32919693e-06, 8.94569111e-06, 10.2214746e-06, 10.2816687e-06])
dadfarnia_thetaT_dis = np.array([0.0, 17.10429e-03, 28.5720978e-03, 32.5279045e-03, 32.7139702e-03])
dadfarnia_thetaT_gb = np.array([0.0, 999.999634e-03, 999.999878e-03, 999.999878e-03, 999.999878e-03])
dadfarnia_thetaT_carb = np.array([0.0, 535.318604e-06, 898.400024e-06, 1.02668393e-03, 1.03238785e-03])

# UVARM data for comparison and calculation outputs
dadfarnia_C_wtppm = np.array([0.0, 693.843445e-03, 1.15232539, 1.3142153, 1.32145774])
dadfarnia_CL_wtppm = np.array([0.0, 576.934326e-03, 968.599548e-03, 1.10681903, 1.11325645])
dadfarnia_CT_wtppm = np.array([0.0, 116.850189e-03, 183.898773e-03, 207.542389e-03, 208.602585e-03])
dadfarnia_CT_dis_wtppm = np.array([0.0, 2.91979527e-03, 4.8773036e-03, 5.55293226e-03, 5.58447313e-03])
dadfarnia_CT_gb_wtppm = np.array([0.0, 17.9380665e-03, 17.9380779e-03, 17.9380779e-03, 17.9380779e-03])
dadfarnia_CT_carb_wtppm = np.array([0.0, 0.09599233, 0.16108339, 0.18405138, 0.18508003])

plt.figure(figsize = (6, 4))
plt.plot(times, dadfarnia_C_wtppm, 'o-', label = 'C wtppm')
plt.title('Hydrogen concentration vs time\nFormulation: Sofronis, Dadfarnia et al. (2011)')
plt.ylim(-0.1, 1.5)
# We now annotate the points with the time values and the C wtppm values
for i, time in enumerate(times):
    plt.annotate(f"{time} min\n{round(dadfarnia_C_wtppm[i], 3)} wt.ppm", (times[i]+6, dadfarnia_C_wtppm[i]-0.2))

plt.yticks(np.arange(0, 1.6, 0.3))
plt.ylabel('H concentration (wt.ppm)')
plt.xlabel('Precharging time (min)')
# Out:
# Text(0.5, 0, 'Precharging time (min)')

# %%
### Now we plot CL, CT, CT_dis, CT_gb, CT_carb for both formulations on same figure
# For Krom et al, we plot with --
# For Dadfarnia et al, we plot with -.

plt.figure(figsize = (6, 4))
plt.plot(times, krom_CL_wtppm, label = r'(Krom) $C_L$ - lattice', linestyle = '--', color='green')
plt.plot(times, dadfarnia_CL_wtppm, label = r'(Dadfarnia) $C_L - lattice$', linestyle = '-.', color='green')

plt.plot(times, krom_CT_dis_wtppm, label = r'(Krom) $C_T$ - dislocation', linestyle = '--', color='red')
plt.plot(times, dadfarnia_CT_dis_wtppm, label = r'(Dadfarnia) $C_T$ - dislocations', linestyle = '-.', color='red')

plt.plot(times, krom_CT_gb_wtppm, label = r'(Krom) $C_T$ - grain boundaries', linestyle = '--', color='purple')
plt.plot(times, dadfarnia_CT_gb_wtppm, label = r'(Dadfarnia) $C_T$ - grain boundaries', linestyle = '-.', color='purple')

plt.plot(times, krom_CT_carb_wtppm, label = r'(Krom) $C_T$ - carbides', linestyle = '--', color='orange')
plt.plot(times, dadfarnia_CT_carb_wtppm, label = r'(Dadfarnia) $C_T$ - carbides', linestyle = '-.', color='orange')

plt.title('Hydrogen concentration vs time')
plt.ylabel('Concentration (wtppm)')
plt.xlabel('Precharging time (min)')
plt.ylim(-0.1, 1.3)
# We want legend to be outside the plot
plt.legend(frameon = False, bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
### Now we plot thetaL, thetaT_dis, thetaT_gb, thetaT_carb for both formulations on same figure
# For Krom et al, we plot with --
# For Dadfarnia et al, we plot with -.

plt.figure(figsize = (6, 4))

# we want to plot log scale
plt.yscale('log')
plt.plot(times, krom_thetaL, label = r'(Krom) $\theta_L$', linestyle = '--', color='green')
plt.plot(times, dadfarnia_thetaL, label = r'(Dadfarnia) $\theta_L$', linestyle = '-.', color='green')

plt.plot(times, krom_thetaT_dis, label = r'(Krom) $\theta_T$ - dislocation', linestyle = '--', color='red')
plt.plot(times, dadfarnia_thetaT_dis, label = r'(Dadfarnia) $\theta_T$ - dislocations', linestyle = '-.', color='red')

plt.plot(times, krom_thetaT_gb, label = r'(Krom) $\theta_T$ - grain boundaries', linestyle = '--', color='purple')
plt.plot(times, dadfarnia_thetaT_gb, label = r'(Dadfarnia) $\theta_T$ - grain boundaries', linestyle = '-.', color='purple')

plt.plot(times, krom_thetaT_carb, label = r'(Krom) $\theta_T$ - carbides', linestyle = '--', color='orange')
plt.plot(times, dadfarnia_thetaT_carb, label = r'(Dadfarnia) $\theta_T$ - carbides', linestyle = '-.', color='orange')

plt.title('Fraction of hydrogen sites actually occupied by hydrogen atoms vs time')
plt.ylabel(r'Fraction of occupied sites - $\theta$')
plt.xlabel('Precharging time (min)')
# We want legend to be outside the plot
plt.legend(frameon = False, bbox_to_anchor=(1.05, 1), loc='upper left')
